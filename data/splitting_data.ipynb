# %%
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np
import sys, os

# %%
im2 = Image.open("/home/ubuntu/xray_gan/data/toytestdata/classes/healthy/00029969_004.png", 'r')
imshow(np.asarray(im2))
